# %% [markdown]
# ## Notes for the pandas section of the "Python and SQL" workshop

# %% [markdown]
# #### you'll need to import surveys.csv and species.csv from the software carpentry website at http://www.datacarpentry.org/python-ecology-lesson/setup/

# %%
import pandas as pd

# %%
surveys_df = pd.read_csv("data/surveys.csv")

# %%
surveys_df
# Out:
#        record_id  month  day  year  plot_id species_id  sex  hindfoot_length  \
# 0              1      7   16  1977        2         NL    M             32.0
# 1              2      7   16  1977        3         NL    M             33.0
# 2              3      7   16  1977        2         DM    F             37.0
# 3              4      7   16  1977        7         DM    M             36.0
# 4              5      7   16  1977        3         DM    M             35.0
# 5              6      7   16  1977        1         PF    M             14.0
# 6              7      7   16  1977        2         PE    F              NaN
# 7              8      7   16  1977        1         DM    M             37.0
# 8              9      7   16  1977        1         DM    F             34.0
# 9             10      7   16  1977        6         PF    F             20.0
# 10            11      7   16  1977        5         DS    F             53.0
# ...

# %%
type(surveys_df)
# Out:
# pandas.core.frame.DataFrame

# %%
surveys_df.dtypes
# Out:
# record_id            int64
# month                int64
# day                  int64
# year                 int64
# plot_id              int64
# species_id          object
# sex                 object
# hindfoot_length    float64
# weight             float64
# dtype: object

# %%
surveys_df.columns
# Out:
# Index(['record_id', 'month', 'day', 'year', 'plot_id', 'species_id', 'sex',
#        'hindfoot_length', 'weight'],
#       dtype='object')

# %%
surveys_df.shape
# Out:
# (35549, 9)

# %%
surveys_df.head()
# Out:
#    record_id  month  day  year  plot_id species_id sex  hindfoot_length  \
# 0          1      7   16  1977        2         NL   M             32.0
# 1          2      7   16  1977        3         NL   M             33.0
# 2          3      7   16  1977        2         DM   F             37.0
# 3          4      7   16  1977        7         DM   M             36.0
# 4          5      7   16  1977        3         DM   M             35.0
#
#    weight
# 0     NaN
# 1     NaN
# 2     NaN
# 3     NaN
# 4     NaN

# %%
surveys_df.tail()
# Out:
#        record_id  month  day  year  plot_id species_id  sex  hindfoot_length  \
# 35544      35545     12   31  2002       15         AH  NaN              NaN
# 35545      35546     12   31  2002       15         AH  NaN              NaN
# 35546      35547     12   31  2002       10         RM    F             15.0
# 35547      35548     12   31  2002        7         DO    M             36.0
# 35548      35549     12   31  2002        5        NaN  NaN              NaN
#
#        weight
# 35544     NaN
# 35545     NaN
# 35546    14.0
# 35547    51.0
# 35548     NaN

# %%
surveys_df[['species_id', 'weight']]
# Out:
#       species_id  weight
# 0             NL     NaN
# 1             NL     NaN
# 2             DM     NaN
# 3             DM     NaN
# 4             DM     NaN
# 5             PF     NaN
# 6             PE     NaN
# 7             DM     NaN
# 8             DM     NaN
# 9             PF     NaN
# 10            DS     NaN
# 11            DM     NaN
# 12            DM     NaN
# 13            DM     NaN
# 14            DM     NaN
# 15            DM     NaN
# 16            DS     NaN
# 17            PP     NaN
# 18            PF     NaN
# 19            DS     NaN
# 20            DM     NaN
# 21            NL     NaN
# 22            DM     NaN
# 23            SH     NaN
# 24            DM     NaN
# 25            DM     NaN
# 26            DM     NaN
# 27            DM     NaN
# 28            PP     NaN
# 29            DS     NaN
# ...          ...     ...
# 35519         SF    36.0
# 35520         DM    48.0
# 35521         DM    45.0
# 35522         DM    44.0
# 35523         PB    27.0
# ...

# %%
pd.unique(surveys_df['species_id'])
# Out:
# array(['NL', 'DM', 'PF', 'PE', 'DS', 'PP', 'SH', 'OT', 'DO', 'OX', 'SS',
#        'OL', 'RM', nan, 'SA', 'PM', 'AH', 'DX', 'AB', 'CB', 'CM', 'CQ',
#        'RF', 'PC', 'PG', 'PH', 'PU', 'CV', 'UR', 'UP', 'ZL', 'UL', 'CS',
#        'SC', 'BA', 'SF', 'RO', 'AS', 'SO', 'PI', 'ST', 'CU', 'SU', 'RX',
#        'PB', 'PL', 'PX', 'CT', 'US'], dtype=object)

# %%
#surveys_df['weight']

# %%
surveys_df['weight'].describe()
# Out:
# count    32283.000000
# mean        42.672428
# std         36.631259
# min          4.000000
# 25%         20.000000
# 50%         37.000000
# 75%         48.000000
# max        280.000000
# Name: weight, dtype: float64

# %%
surveys_df['weight'].std()
# Out:
# 36.63125947458399

# %%
grouped_data = surveys_df.groupby('sex')

# %%
pd.set_option('display.max_columns', 500)

# %%
grouped_data.describe()
# Out:
#     record_id                                                               \
#         count          mean           std  min      25%      50%       75%
# sex
# F     15690.0  18036.412046  10423.089000  3.0  8917.50  18075.5  27250.00
# M     17348.0  17754.835601  10132.203323  1.0  8969.75  17727.5  26454.25
#
#                 month                                                     day  \
#          max    count      mean       std  min  25%  50%   75%   max    count
# sex
# F    35547.0  15690.0  6.587253  3.367584  1.0  4.0  7.0  10.0  12.0  15690.0
# M    35548.0  17348.0  6.396184  3.421134  1.0  3.0  6.0  10.0  12.0  17348.0
#
#                                                          year               \
#           mean       std  min  25%   50%   75%   max    count         mean
# sex
# F    15.880943  8.270291  1.0  9.0  15.0  23.0  31.0  15690.0  1990.644997
# M    16.078799  8.200967  1.0  9.0  16.0  23.0  31.0  17348.0  1990.480401
#
# ...

# %%
grouped_data2 = surveys_df.groupby(['plot_id','sex'])

# %%
#grouped_data2.describe()

# %%
plot_df = surveys_df.groupby(['plot_id'])

# %%
#plot_df['weight'].describe()

# %%
surveys_df[['plot_id', 'species_id']][0:3]
# Out:
#    plot_id species_id
# 0        2         NL
# 1        3         NL
# 2        2         DM

# %%
surveys_df.iloc[10:15,1:4]
# Out:
#     month  day  year
# 10      7   16  1977
# 11      7   16  1977
# 12      7   16  1977
# 13      7   16  1977
# 14      7   16  1977

# %%
surveys_df.iloc[0:3, [1,4]]
# Out:
#    month  plot_id
# 0      7        2
# 1      7        3
# 2      7        2

# %%
surveys_df.loc[0:3, ['species_id','month','day','year']]
# Out:
#   species_id  month  day  year
# 0         NL      7   16  1977
# 1         NL      7   16  1977
# 2         DM      7   16  1977
# 3         DM      7   16  1977

# %%
#surveys_df[surveys_df.year != 2002]

# %%
#surveys_df[(surveys_df.year >= 1980) & (surveys_df.year <= 1985)]

# %%
#vertical stacking

# %%
first_ten = surveys_df.head(10)

# %%
last_ten = surveys_df.tail(10).reset_index(drop=True)

# %%
#last_ten

# %%
vertical_stack = pd.concat([first_ten, last_ten], axis=1)

# %%
#vertical_stack

# %%
species_df = pd.read_csv("data/species.csv")

# %%
#species_df

# %%
survey_sub = surveys_df.head(10)

# %%
#survey_sub

# %%
species_df.columns
# Out:
# Index(['species_id', 'genus', 'species', 'taxa'], dtype='object')

# %%
inner_join_df = pd.merge(left=species_df, right=surveys_df, 
                         left_on='species_id', right_on='species_id')

#inner_join_df = pd.merge(left=survey_sub, right=species_df, 
#                         on='species_id')

# %%
inner_join_df
inner_join_df.sort_values(['record_id'])
inner_join_df.reset_index()
# Out:
#        index species_id        genus     species     taxa  record_id  month  \
# 0          0         AB   Amphispiza   bilineata     Bird       3126      7
# 1          1         AB   Amphispiza   bilineata     Bird       3146      7
# 2          2         AB   Amphispiza   bilineata     Bird       3152      7
# 3          3         AB   Amphispiza   bilineata     Bird       3153      7
# 4          4         AB   Amphispiza   bilineata     Bird       3586     12
# 5          5         AB   Amphispiza   bilineata     Bird       3702      1
# 6          6         AB   Amphispiza   bilineata     Bird       3705      1
# 7          7         AB   Amphispiza   bilineata     Bird       3706      1
# 8          8         AB   Amphispiza   bilineata     Bird       3775      1
# 9          9         AB   Amphispiza   bilineata     Bird       4499      6
# 10        10         AB   Amphispiza   bilineata     Bird       4543      6
# ...

# %%
left_outer_join_df = pd.merge(left=species_df, right=surveys_df, how='left', 
                         left_on='species_id', right_on='species_id')

# %%
left_outer_join_df
# Out:
#       species_id        genus     species     taxa  record_id  month   day  \
# 0             AB   Amphispiza   bilineata     Bird     3126.0    7.0  21.0
# 1             AB   Amphispiza   bilineata     Bird     3146.0    7.0  21.0
# 2             AB   Amphispiza   bilineata     Bird     3152.0    7.0  21.0
# 3             AB   Amphispiza   bilineata     Bird     3153.0    7.0  21.0
# 4             AB   Amphispiza   bilineata     Bird     3586.0   12.0  15.0
# 5             AB   Amphispiza   bilineata     Bird     3702.0    1.0  11.0
# 6             AB   Amphispiza   bilineata     Bird     3705.0    1.0  11.0
# 7             AB   Amphispiza   bilineata     Bird     3706.0    1.0  11.0
# 8             AB   Amphispiza   bilineata     Bird     3775.0    1.0  12.0
# 9             AB   Amphispiza   bilineata     Bird     4499.0    6.0   4.0
# 10            AB   Amphispiza   bilineata     Bird     4543.0    6.0   4.0
# ...

# %%
inner_join_df = pd.merge(left=surveys_df,right=species_df,left_on='species_id',right_on='species_id')

# %%
#inner_join_df[(inner_join_df.year > 1980)]

# %%
grouped_genus = inner_join_df.dropna(subset = ['hindfoot_length']).groupby(['genus'])

# %%
describe_genus = grouped_genus.hindfoot_length.describe()

# %%
describe_genus.describe()
# Out:
#               count       mean        std        min        25%       50%  \
# count     10.000000  10.000000  10.000000  10.000000  10.000000  10.00000
# mean    3143.800000  24.059044   2.316403  12.600000  22.900000  23.80000
# std     4526.753676   8.355718   1.208293   8.591986   7.823753   7.91342
# min        2.000000  13.000000   1.151236   2.000000  12.000000  13.00000
# 25%      428.250000  17.424945   1.449470   6.250000  17.000000  17.75000
# 50%     1809.500000  22.106675   2.025847  11.000000  21.000000  22.00000
# 75%     2931.500000  31.130295   2.748427  15.750000  29.750000  30.75000
# max    14991.000000  37.896471   5.165592  31.000000  35.000000  36.00000
#
#              75%        max
# count  10.000000  10.000000
# mean   24.900000  41.700000
# std     8.252272  16.806414
# min    14.000000  16.000000
# 25%    18.000000  35.250000
# 50%    23.500000  38.500000
# 75%    32.250000  49.250000
# max    37.000000  70.000000
